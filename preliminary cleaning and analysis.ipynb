# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/College_Scorecard_Raw_Data_10032025/MERGED2010_11_PP.csv", low_memory=False)

# %%
# dropping columsn with <1 non-NaN values
dfDropped = df.dropna(axis=1, thresh = 1);
dfDropped.shape
# Out:
# (7470, 1621)

# %%
df["MN_EARN_WNE_P6"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 7465   NaN
# 7466   NaN
# 7467   NaN
# 7468   NaN
# 7469   NaN
# Name: MN_EARN_WNE_P6, Length: 7470, dtype: float64
